# %%
import pandas as pd
df = pd.read_csv('../resources/acs2017_county_data.csv')

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
df.columns
# Out:
# Index(['CountyId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
yy=df.loc[df['State']=='California']
print(df.shape)
print(yy.shape)
# Out:
# (3220, 37)
# (58, 37)

# %%
df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
yy=df.loc[df['State']=='California'][['State','CountyId']]
print(yy.shape)
yy.head(54)
yy.info()
# Out:
# (58, 2)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 186 to 243
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   State     58 non-null     object
#  1   CountyId  58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
usda=pd.read_excel('../resources/ruralurbancodes2013.xls')

# %%
usda.columns
# Out:
# Index(['FIPS', 'State', 'County_Name', 'Population_2010', 'RUCC_2013',
#        'Description'],
#       dtype='object')

# %%
statesList = []
for i in usda['State'].unique():
    statesList.append(i)
print(statesList)
# Out:
# ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR']

# %%
statesArr=usda['State'].unique()
statesArr.dtype
# Out:
# dtype('O')

# %%
zz=usda.loc[usda['State']=='CA'][['State','FIPS']]
print(zz.shape)
zz.info()
# Out:
# (58, 2)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 186 to 243
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   58 non-null     object
#  1   FIPS    58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
zz.head(54)
# Out:
#     State  FIPS
# 186    CA  6001
# 187    CA  6003
# 188    CA  6005
# 189    CA  6007
# 190    CA  6009
# 191    CA  6011
# 192    CA  6013
# 193    CA  6015
# 194    CA  6017
# 195    CA  6019
# 196    CA  6021
# 197    CA  6023
# 198    CA  6025
# 199    CA  6027
# 200    CA  6029
# 201    CA  6031
# 202    CA  6033
# 203    CA  6035
# 204    CA  6037
# 205    CA  6039
# 206    CA  6041
# 207    CA  6043
# 208    CA  6045
# 209    CA  6047
# 210    CA  6049
# 211    CA  6051
# 212    CA  6053
# 213    CA  6055
# 214    CA  6057
# 215    CA  6059
# 216    CA  6061
# 217    CA  6063
# 218    CA  6065
# 219    CA  6067
# 220    CA  6069
# 221    CA  6071
# 222    CA  6073
# 223    CA  6075
# 224    CA  6077
# 225    CA  6079
# 226    CA  6081
# 227    CA  6083
# 228    CA  6085
# 229    CA  6087
# 230    CA  6089
# 231    CA  6091
# 232    CA  6093
# 233    CA  6095
# 234    CA  6097
# 235    CA  6099
# 236    CA  6101
# 237    CA  6103
# 238    CA  6105
# 239    CA  6107

# %%
usda.sample(10)
# Out:
#        FIPS State          County_Name  Population_2010  RUCC_2013  \
# 2754  48463    TX        Uvalde County            26405          6
# 657   17125    IL         Mason County            14666          6
# 3136  56033    WY      Sheridan County            29116          7
# 1252  26043    MI     Dickinson County            26168          7
# 1092  21199    KY       Pulaski County            63063          5
# 2107  39129    OH      Pickaway County            55698          1
# 1006  21027    KY  Breckinridge County            20059          8
# 2094  39103    OH        Medina County           172332          1
# 1531  29097    MO        Jasper County           117404          3
# 481   13191    GA      McIntosh County            14333          3
#
#                                             Description
# 2754  Nonmetro - Urban population of 2,500 to 19,999...
# 657   Nonmetro - Urban population of 2,500 to 19,999...
# 3136  Nonmetro - Urban population of 2,500 to 19,999...
# ...

# %%
usda.groupby('RUCC_2013')[['RUCC_2013','Description','County_Name','Population_2010','State']].max()
# Out:
#            RUCC_2013                                        Description
# RUCC_2013
# 1                  1  Metro - Counties in metro areas of 1 million p...
# 2                  2  Metro - Counties in metro areas of 250,000 to ...
# 3                  3  Metro - Counties in metro areas of fewer than ...
# 4                  4  Nonmetro - Urban population of 20,000 or more,...
# 5                  5  Nonmetro - Urban population of 20,000 or more,...
# 6                  6  Nonmetro - Urban population of 2,500 to 19,999...
# 7                  7  Nonmetro - Urban population of 2,500 to 19,999...
# 8                  8  Nonmetro - Completely rural or less than 2,500...
# 9                  9  Nonmetro - Completely rural or less than 2,500...

# %%
print(usda.shape)
# Out:
# (3221, 6)

# %%
xx=usda.loc[usda['State']=='CA']
print(xx.shape)
xx.sample(20)
# Out:
# (58, 6)
#      FIPS State             County_Name  Population_2010  RUCC_2013  \
# 224  6077    CA      San Joaquin County           685306          2
# 216  6061    CA           Placer County           348432          1
# 189  6007    CA            Butte County           220000          3
# 231  6091    CA           Sierra County             3240          8
# 232  6093    CA         Siskiyou County            44900          6
# 241  6111    CA          Ventura County           823318          2
# 209  6047    CA           Merced County           255793          2
# 193  6015    CA        Del Norte County            28610          7
# 230  6089    CA           Shasta County           177223          3
# 242  6113    CA             Yolo County           200849          1
# 238  6105    CA          Trinity County            13786          8
# 233  6095    CA           Solano County           413344          2
# 195  6019    CA           Fresno County           930450          2
# ...

# %%
va = df.loc[df['State']=='California']
va2=pd.merge(va, usda, left_on='CountyId', right_on='FIPS', how='left')
print(va.shape)
print(va2.shape)
# Out:
# (58, 37)
# (58, 43)

# %%
usofa.sample(2)
# Out:
#       CountyId       State_x         County  TotalPop    Men  Women  Hispanic  \
# 2363     46005  South Dakota  Beadle County     18163   9219   8944       9.1
# 2483     47111     Tennessee   Macon County     23239  11381  11858       5.1
#
#       White  Black  Native  ...  PublicWork  SelfEmployed  FamilyWork  \
# 2363   79.5    0.4     1.4  ...        12.9           9.5         0.3
# 2483   92.1    0.4     0.4  ...        13.0          10.7         0.0
#
#       Unemployment     FIPS  State_y    County_Name  Population_2010  \
# 2363           2.1  46005.0       SD  Beadle County          17398.0
# 2483           5.8  47111.0       TN   Macon County          22248.0
#
#       RUCC_2013                                        Description
# 2363        7.0  Nonmetro - Urban population of 2,500 to 19,999...
# 2483        1.0  Metro - Counties in metro areas of 1 million p...
#
# [2 rows x 43 columns]

# %%
usofa.columns
# Out:
# Index(['CountyId', 'State_x', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'FIPS', 'State_y',
#        'County_Name', 'Population_2010', 'RUCC_2013', 'Description'],
#       dtype='object')

# %%
usofa.

# %%
state = usofa.loc[usofa['State_y']=='CA']

print(state.shape)
# Out:
# (58, 43)

# %%
state.sample(10)
# Out:
#      CountyId     State_x                 County  TotalPop      Men    Women  \
# 221      6071  California  San Bernardino County   2121220  1055170  1066050
# 237      6103  California          Tehama County     63247    31452    31795
# 201      6031  California           Kings County    150183    82982    67201
# 242      6113  California            Yolo County    212605   103617   108988
# 212      6053  California        Monterey County    433168   221016   212152
# 224      6077  California     San Joaquin County    724153   360247   363906
# 234      6097  California          Sonoma County    500943   245381   255562
# 195      6019  California          Fresno County    971616   484667   486949
# 205      6039  California          Madera County    154440    74583    79857
# 197      6023  California        Humboldt County    135490    67508    67982
#
#      Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# ...

# %%
state = usofa.loc[usofa['State_y']=='CA']

print(state.shape)
# Out:
# (58, 43)

# %%
state.sample(58)
# Out:
#      CountyId     State_x                  County  TotalPop      Men    Women  \
# 190      6009  California        Calaveras County     45057    22292    22765
# 191      6011  California           Colusa County     21479    11157    10322
# 187      6003  California           Alpine County      1203      664      539
# 217      6063  California           Plumas County     18724     9432     9292
# 242      6113  California             Yolo County    212605   103617   108988
# 240      6109  California         Tuolumne County     53899    28029    25870
# 204      6037  California      Los Angeles County  10105722  4979641  5126081
# 231      6091  California           Sierra County      2885     1488     1397
# 230      6089  California           Shasta County    178919    87753    91166
# 235      6099  California       Stanislaus County    535684   264824   270860
# 197      6023  California         Humboldt County    135490    67508    67982
# ...

# %%
usofa.loc[usofa['FIPS'].isna()][['CountyId','FIPS']]
# Out:
#       CountyId  FIPS
# 81        2158   NaN
# 2412     46102   NaN

# %%
usofa.loc[usofa['State_y'].isna()][['CountyId','State_y']]
# Out:
#       CountyId State_y
# 81        2158     NaN
# 2412     46102     NaN

# %%
usofa.isna().sum()
# Out:
# CountyId            0
# State_x             0
# County              0
# TotalPop            0
# Men                 0
# Women               0
# Hispanic            0
# White               0
# Black               0
# Native              0
# Asian               0
# Pacific             0
# VotingAgeCitizen    0
# Income              0
# IncomeErr           0
# IncomePerCap        0
# IncomePerCapErr     0
# Poverty             0
# ChildPoverty        1
# Professional        0
# Service             0
# Office              0
# Construction        0
# Production          0
# Drive               0
# Carpool             0
# Transit             0
# Walk                0
# OtherTransp         0
# WorkAtHome          0
# MeanCommute         0
# Employed            0
# PrivateWork         0
# PublicWork          0
# SelfEmployed        0
# FamilyWork          0
# Unemployment        0
# FIPS                2
# State_y             2
# County_Name         2
# Population_2010     2
# ...

# %%
usofa = usofa.dropna()

# %%
usofa.loc[usofa['Population_2010'].isna()][['CountyId','Population_2010']]
# Out:
# Empty DataFrame
# Columns: [CountyId, Population_2010]
# Index: []

# %%
pd.isnull(usofa)
# Out:
#       CountyId  State_x  County  TotalPop    Men  Women  Hispanic  White  \
# 0        False    False   False     False  False  False     False  False
# 1        False    False   False     False  False  False     False  False
# 2        False    False   False     False  False  False     False  False
# 3        False    False   False     False  False  False     False  False
# 4        False    False   False     False  False  False     False  False
# ...        ...      ...     ...       ...    ...    ...       ...    ...
# 3215     False    False   False     False  False  False     False  False
# 3216     False    False   False     False  False  False     False  False
# 3217     False    False   False     False  False  False     False  False
# 3218     False    False   False     False  False  False     False  False
# 3219     False    False   False     False  False  False     False  False
#
#       Black  Native  ...  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# ...
