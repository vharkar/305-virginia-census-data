# %%
import pandas as pd
df = pd.read_csv('../resources/acs2017_county_data.csv')

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 2.6 MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0     24112         74.1        20.2           5.6         0.1           5.2
# 1     89527         80.7        12.9           6.3         0.1           5.5
# 2      8878         74.1        19.1           6.5         0.3          12.4
# 3      8171         76.0        17.4           6.3         0.3           8.2
# 4     21380         83.9        11.9           4.0         0.1           4.9
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['CountyId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
usda=pd.read_excel('../resources/ruralurbancodes2013.xls')

# %%
usda.columns
# Out:
# Index(['FIPS', 'State', 'County_Name', 'Population_2010', 'RUCC_2013',
#        'Description'],
#       dtype='object')

# %%
usda.sample(10)
# Out:
#        FIPS State               County_Name  Population_2010  RUCC_2013  \
# 1527  29089    MO             Howard County            10144          6
# 722   18051    IN             Gibson County            33503          6
# 742   18091    IN            LaPorte County           111467          3
# 1233  26005    MI            Allegan County           111408          4
# 2620  48195    TX           Hansford County             5613          7
# 85     2188    AK  Northwest Arctic Borough             7523          7
# 2680  48315    TX             Marion County            10546          8
# 2583  48121    TX             Denton County           662614          1
# 3008  54031    WV              Hardy County            14025          6
# 1069  21153    KY           Magoffin County            13333          9
#
#                                             Description
# 1527  Nonmetro - Urban population of 2,500 to 19,999...
# 722   Nonmetro - Urban population of 2,500 to 19,999...
# 742   Metro - Counties in metro areas of fewer than ...
# 1233  Nonmetro - Urban population of 20,000 or more,...
# 2620  Nonmetro - Urban population of 2,500 to 19,999...
# 85    Nonmetro - Urban population of 2,500 to 19,999...
# 2680  Nonmetro - Completely rural or less than 2,500...
# 2583  Metro - Counties in metro areas of 1 million p...
# 3008  Nonmetro - Urban population of 2,500 to 19,999...
# 1069  Nonmetro - Completely rural or less than 2,500...

# %%
usda=usda.groupby('RUCC_2013')[['RUCC_2013','Description']].max()

# %%
usofa=pd.merge(df, usda, left_on='CountyId', right_on='FIPS', how='left')
print(usofa.shape)
print(usda.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_421/2376707921.py in <module>
# ----> 1 usofa=pd.merge(df, usda, left_on='CountyId', right_on='FIPS', how='left')
#       2 print(usofa.shape)
#       3 print(usda.shape)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# --> 700         ) = self._get_merge_keys()
#     701
#     702         # validate the merge keys dtypes. We may need to coerce
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1095                     if not is_rkey(rk):
#    1096                         if rk is not None:
# -> 1097                             right_keys.append(right._get_label_or_level_values(rk))
#    1098                         else:
#    1099                             # work-around for merge_asof(right_index=True)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1846             values = self.axes[axis].get_level_values(key)._values
#    1847         else:
# -> 1848             raise KeyError(key)
#    1849
#    1850         # Check for duplicates
#
# KeyError: 'FIPS'

# %%
usofa.sample(2)
# Out:
#       CountyId     State_x           County  TotalPop     Men   Women  \
# 1786     34025  New Jersey  Monmouth County    627551  305192  322359
# 621      17053    Illinois      Ford County     13470    6647    6823
#
#       Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# 1786      10.6   75.4    6.7     0.1  ...        13.8           5.3
# 621        3.0   94.3    0.9     0.4  ...        11.0          10.7
#
#       FamilyWork  Unemployment     FIPS  State_y      County_Name  \
# 1786         0.2           6.0  34025.0       NJ  Monmouth County
# 621          0.2           6.6  17053.0       IL      Ford County
#
#       Population_2010  RUCC_2013  \
# 1786         630380.0        1.0
# 621           14081.0        3.0
#
#                                             Description
# 1786  Metro - Counties in metro areas of 1 million p...
# 621   Metro - Counties in metro areas of fewer than ...
#
# [2 rows x 43 columns]
