# %%
import pandas as pd
df = pd.read_csv('../resources/acs2017_county_data.csv')

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 2.6 MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0     24112         74.1        20.2           5.6         0.1           5.2
# 1     89527         80.7        12.9           6.3         0.1           5.5
# 2      8878         74.1        19.1           6.5         0.3          12.4
# 3      8171         76.0        17.4           6.3         0.3           8.2
# 4     21380         83.9        11.9           4.0         0.1           4.9
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['CountyId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
yy=df.loc[df['State']=='Arkansas']
yy.sample(20)
# Out:
#      CountyId     State              County  TotalPop     Men   Women  \
# 135      5049  Arkansas       Fulton County     12092    5947    6145
# 139      5057  Arkansas    Hempstead County     22154   10380   11774
# 140      5059  Arkansas   Hot Spring County     33480   17294   16186
# 131      5041  Arkansas        Desha County     12094    5547    6547
# 132      5043  Arkansas         Drew County     18620    9090    9530
# 182      5143  Arkansas   Washington County    223683  111839  111844
# 134      5047  Arkansas     Franklin County     17803    8674    9129
# 177      5133  Arkansas       Sevier County     17206    8612    8594
# 126      5031  Arkansas    Craighead County    104246   50774   53472
# 121      5021  Arkansas         Clay County     15190    7421    7769
# 157      5093  Arkansas  Mississippi County     43534   21030   22504
# 173      5125  Arkansas       Saline County    116252   57280   58972
# 185      5149  Arkansas         Yell County     21601   10722   10879
# 156      5091  Arkansas       Miller County     43760   21581   22179
# 176      5131  Arkansas    Sebastian County    127362   62180   65182
# 153      5085  Arkansas       Lonoke County     71568   35222   36346
# 167      5113  Arkansas         Polk County     20212    9869   10343
# 130      5039  Arkansas       Dallas County      7585    3639    3946
# 160      5099  Arkansas       Nevada County      8528    4444    4084
# 181      5141  Arkansas    Van Buren County     16751    8356    8395
#
#      Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# 135       1.3   95.6    0.3     0.9  ...   0.7          1.2         3.3
# 139      12.5   55.2   29.5     0.3  ...   1.3          1.1         3.1
# 140       3.4   82.8   10.9     0.3  ...   1.4          0.5         1.4
# 131       5.8   45.7   47.5     0.1  ...   1.5          2.1         1.5
# 132       3.1   66.9   28.8     0.1  ...   2.9          1.3         1.7
# 182      16.5   71.9    3.4     0.8  ...   2.1          1.3         3.5
# 134       2.9   92.4    1.0     1.6  ...   2.4          0.6         5.1
# 177      32.9   58.3    4.8     1.6  ...   0.8          0.8         2.0
# 126       4.9   77.3   13.4     0.2  ...   2.3          0.7         3.3
# 121       1.9   95.8    0.7     0.5  ...   3.1          0.5         1.9
# 157       4.0   58.7   35.1     0.0  ...   0.7          1.0         1.3
# 173       4.5   85.9    6.4     0.3  ...   0.5          1.1         2.7
# 185      19.7   75.6    2.0     0.8  ...   2.2          2.2         6.0
# 156       3.1   69.4   24.4     0.7  ...   1.3          1.1         2.0
# 176      13.7   70.4    6.7     1.1  ...   1.8          1.8         2.3
# 153       4.3   86.5    6.0     0.5  ...   2.0          0.7         2.6
# 167       6.4   88.0    0.5     1.1  ...   1.0          0.8         2.5
# 130       3.1   53.2   40.0     0.4  ...   5.6          2.2         1.9
# 160       0.4   63.4   33.4     0.1  ...   1.1          1.9         2.7
# 181       2.9   93.7    0.4     0.6  ...   1.8          1.7         3.8
#
#      MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 135         23.3      4132         73.1        17.6           9.0         0.4
# 139         19.9      8819         75.4        17.4           6.8         0.4
# 140         26.1     13378         79.3        15.3           5.1         0.4
# 131         19.3      4440         68.6        26.9           4.5         0.0
# 132         21.7      7629         71.0        21.9           7.0         0.0
# 182         21.5    106905         79.4        14.8           5.7         0.1
# 134         26.8      6598         74.1        20.0           5.6         0.3
# 177         25.8      7225         76.6        15.2           8.2         0.0
# 126         18.5     48216         80.1        13.4           6.2         0.2
# 121         23.3      6234         80.6        11.5           7.9         0.0
# 157         17.8     17270         77.2        16.7           5.9         0.2
# 173         26.1     55741         78.9        16.6           4.5         0.1
# 185         20.8      8852         78.7        14.4           6.6         0.3
# 156         18.4     18399         77.0        15.9           7.1         0.0
# 176         19.0     55376         85.3         9.9           4.6         0.2
# 153         27.3     32577         76.8        18.1           4.9         0.2
# 167         23.0      7222         72.6        17.1          10.3         0.0
# 130         27.5      2910         72.2        23.7           3.8         0.3
# 160         29.9      3294         73.2        22.7           4.2         0.0
# 181         27.9      5646         75.5        12.6          11.8         0.0
#
#      Unemployment
# 135           6.9
# 139           6.4
# 140           6.2
# 131          12.2
# 132           9.0
# 182           4.9
# 134           6.6
# 177           6.6
# 126           6.0
# 121           5.3
# 157          11.6
# 173           4.3
# 185           6.3
# 156           8.0
# 176           5.6
# 153           4.8
# 167           8.5
# 130           6.4
# 160           4.8
# 181           8.3
#
# [20 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# CountyId            0
# State               0
# County              0
# TotalPop            0
# Men                 0
# Women               0
# Hispanic            0
# White               0
# Black               0
# Native              0
# Asian               0
# Pacific             0
# VotingAgeCitizen    0
# Income              0
# IncomeErr           0
# IncomePerCap        0
# IncomePerCapErr     0
# Poverty             0
# ChildPoverty        1
# Professional        0
# Service             0
# Office              0
# Construction        0
# Production          0
# Drive               0
# Carpool             0
# Transit             0
# Walk                0
# OtherTransp         0
# WorkAtHome          0
# MeanCommute         0
# Employed            0
# PrivateWork         0
# PublicWork          0
# SelfEmployed        0
# FamilyWork          0
# Unemployment        0
# dtype: int64

# %%
usda=pd.read_excel('../resources/ruralurbancodes2013.xls')

# %%
usda.columns
# Out:
# Index(['FIPS', 'State', 'County_Name', 'Population_2010', 'RUCC_2013',
#        'Description'],
#       dtype='object')

# %%
usda.isnull().sum()
# Out:
# FIPS               0
# State              0
# County_Name        0
# Population_2010    0
# RUCC_2013          0
# Description        0
# dtype: int64

# %%
usda.sample(10)
# Out:
#        FIPS State       County_Name  Population_2010  RUCC_2013  \
# 1074  21163    KY      Meade County            28602          3
# 1287  26113    MI  Missaukee County            14849          9
# 1140  22055    LA  Lafayette Parish           221578          2
# 287    8085    CO   Montrose County            41276          4
# 3036  54087    WV      Roane County            14926          6
# 3150  72015    PR  Arroyo Municipio            19575          3
# 2139  40017    OK   Canadian County           115541          1
# 269    8049    CO      Grand County            14843          7
# 1367  27107    MN     Norman County             6852          8
# 34     1069    AL    Houston County           101547          3
#
#                                             Description
# 1074  Metro - Counties in metro areas of fewer than ...
# 1287  Nonmetro - Completely rural or less than 2,500...
# 1140  Metro - Counties in metro areas of 250,000 to ...
# 287   Nonmetro - Urban population of 20,000 or more,...
# 3036  Nonmetro - Urban population of 2,500 to 19,999...
# 3150  Metro - Counties in metro areas of fewer than ...
# 2139  Metro - Counties in metro areas of 1 million p...
# 269   Nonmetro - Urban population of 2,500 to 19,999...
# 1367  Nonmetro - Completely rural or less than 2,500...
# 34    Metro - Counties in metro areas of fewer than ...

# %%
usda.groupby('RUCC_2013')[['RUCC_2013','Description']].max()
# Out:
#            RUCC_2013                                        Description
# RUCC_2013
# 1                  1  Metro - Counties in metro areas of 1 million p...
# 2                  2  Metro - Counties in metro areas of 250,000 to ...
# 3                  3  Metro - Counties in metro areas of fewer than ...
# 4                  4  Nonmetro - Urban population of 20,000 or more,...
# 5                  5  Nonmetro - Urban population of 20,000 or more,...
# 6                  6  Nonmetro - Urban population of 2,500 to 19,999...
# 7                  7  Nonmetro - Urban population of 2,500 to 19,999...
# 8                  8  Nonmetro - Completely rural or less than 2,500...
# 9                  9  Nonmetro - Completely rural or less than 2,500...

# %%
xx=usda.loc[usda['State']=='AR']
print(xx.shape)
xx.sample(20)
# Out:
# (75, 6)
#      FIPS State          County_Name  Population_2010  RUCC_2013  \
# 172  5123    AR   St. Francis County            28258          6
# 159  5097    AR    Montgomery County             9487          8
# 148  5075    AR      Lawrence County            17415          6
# 140  5059    AR    Hot Spring County            32923          6
# 151  5081    AR  Little River County            13171          3
# 155  5089    AR        Marion County            16653          9
# 117  5013    AR       Calhoun County             5368          9
# 128  5035    AR    Crittenden County            50902          1
# 114  5007    AR        Benton County           221339          2
# 176  5131    AR     Sebastian County           125744          2
# 131  5041    AR         Desha County            13008          6
# 173  5125    AR        Saline County           107118          2
# 166  5111    AR      Poinsett County            24583          3
# 175  5129    AR        Searcy County             8195          9
# 163  5105    AR         Perry County            10445          2
# 146  5071    AR       Johnson County            25540          7
# 184  5147    AR      Woodruff County             7260          9
# 183  5145    AR         White County            77076          4
# 133  5045    AR      Faulkner County           113237          2
# 153  5085    AR        Lonoke County            68356          2
#
#                                            Description
# 172  Nonmetro - Urban population of 2,500 to 19,999...
# 159  Nonmetro - Completely rural or less than 2,500...
# 148  Nonmetro - Urban population of 2,500 to 19,999...
# 140  Nonmetro - Urban population of 2,500 to 19,999...
# 151  Metro - Counties in metro areas of fewer than ...
# 155  Nonmetro - Completely rural or less than 2,500...
# 117  Nonmetro - Completely rural or less than 2,500...
# 128  Metro - Counties in metro areas of 1 million p...
# 114  Metro - Counties in metro areas of 250,000 to ...
# 176  Metro - Counties in metro areas of 250,000 to ...
# 131  Nonmetro - Urban population of 2,500 to 19,999...
# 173  Metro - Counties in metro areas of 250,000 to ...
# 166  Metro - Counties in metro areas of fewer than ...
# 175  Nonmetro - Completely rural or less than 2,500...
# 163  Metro - Counties in metro areas of 250,000 to ...
# 146  Nonmetro - Urban population of 2,500 to 19,999...
# 184  Nonmetro - Completely rural or less than 2,500...
# 183  Nonmetro - Urban population of 20,000 or more,...
# 133  Metro - Counties in metro areas of 250,000 to ...
# 153  Metro - Counties in metro areas of 250,000 to ...

# %%
usofa=pd.merge(df, usda, left_on='CountyId', right_on='FIPS', how='left')
print(usofa.shape)
print(usda.shape)
# Out:
# (3220, 43)
# (3221, 6)

# %%
usofa.sample(2)
# Out:
#       CountyId    State_x             County  TotalPop    Men  Women  \
# 2901     51171   Virginia  Shenandoah County     42854  20850  22004
# 2444     47033  Tennessee    Crockett County     14554   6915   7639
#
#       Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# 2901       6.9   88.4    1.7     0.1  ...        16.7           7.2
# 2444      10.1   74.7   13.2     0.2  ...        14.1           6.4
#
#       FamilyWork  Unemployment     FIPS  State_y        County_Name  \
# 2901         0.4           5.2  51171.0       VA  Shenandoah County
# 2444         0.1           5.9  47033.0       TN    Crockett County
#
#       Population_2010  RUCC_2013  \
# 2901          41993.0        6.0
# 2444          14586.0        3.0
#
#                                             Description
# 2901  Nonmetro - Urban population of 2,500 to 19,999...
# 2444  Metro - Counties in metro areas of fewer than ...
#
# [2 rows x 43 columns]

# %%
usofa.columns
# Out:
# Index(['CountyId', 'State_x', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'FIPS', 'State_y',
#        'County_Name', 'Population_2010', 'RUCC_2013', 'Description'],
#       dtype='object')

# %%
state = usofa.loc[usofa['State_y']=='CA']

print(state.shape)
# Out:
# (58, 43)

# %%
state.sample(10)
# Out:
#      CountyId     State_x              County  TotalPop      Men    Women  \
# 191      6011  California       Colusa County     21479    11157    10322
# 204      6037  California  Los Angeles County  10105722  4979641  5126081
# 235      6099  California   Stanislaus County    535684   264824   270860
# 214      6057  California       Nevada County     98838    48732    50106
# 202      6033  California         Lake County     64095    31788    32307
# 232      6093  California     Siskiyou County     43530    21706    21824
# 224      6077  California  San Joaquin County    724153   360247   363906
# 226      6081  California    San Mateo County    763450   376145   387305
# 238      6105  California      Trinity County     13037     6603     6434
# 190      6009  California    Calaveras County     45057    22292    22765
#
#      Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# 191      58.4   36.3    0.9     1.1  ...        13.4           9.7
# 204      48.4   26.5    7.9     0.2  ...        11.2           9.3
# 235      45.0   43.4    2.5     0.4  ...        13.8           6.7
# 214       9.2   85.4    0.5     0.7  ...        14.5          15.7
# 202      19.4   71.7    2.1     3.2  ...        20.0          11.4
# 232      12.0   77.2    1.5     2.9  ...        22.5          14.3
# 224      40.8   33.2    6.7     0.2  ...        14.4           6.4
# 226      24.9   39.9    2.3     0.1  ...        11.3           8.0
# 238       7.2   82.8    0.8     4.3  ...        30.8          16.9
# 190      11.5   82.0    0.6     0.9  ...        18.2          13.7
#
#      FamilyWork  Unemployment    FIPS  State_y         County_Name  \
# 191         0.2           5.9  6011.0       CA       Colusa County
# 204         0.2           7.8  6037.0       CA  Los Angeles County
# 235         0.2          11.8  6099.0       CA   Stanislaus County
# 214         0.6           7.3  6057.0       CA       Nevada County
# 202         0.3          11.2  6033.0       CA         Lake County
# 232         0.3           9.1  6093.0       CA     Siskiyou County
# 224         0.2          10.1  6077.0       CA  San Joaquin County
# 226         0.2           4.7  6081.0       CA    San Mateo County
# 238         6.1           9.6  6105.0       CA      Trinity County
# 190         0.4           7.1  6009.0       CA    Calaveras County
#
#      Population_2010  RUCC_2013  \
# 191          21419.0        6.0
# 204        9818605.0        1.0
# 235         514453.0        2.0
# 214          98764.0        4.0
# 202          64665.0        4.0
# 232          44900.0        6.0
# 224         685306.0        2.0
# 226         718451.0        1.0
# 238          13786.0        8.0
# 190          45578.0        6.0
#
#                                            Description
# 191  Nonmetro - Urban population of 2,500 to 19,999...
# 204  Metro - Counties in metro areas of 1 million p...
# 235  Metro - Counties in metro areas of 250,000 to ...
# 214  Nonmetro - Urban population of 20,000 or more,...
# 202  Nonmetro - Urban population of 20,000 or more,...
# 232  Nonmetro - Urban population of 2,500 to 19,999...
# 224  Metro - Counties in metro areas of 250,000 to ...
# 226  Metro - Counties in metro areas of 1 million p...
# 238  Nonmetro - Completely rural or less than 2,500...
# 190  Nonmetro - Urban population of 2,500 to 19,999...
#
# [10 rows x 43 columns]

# %%
state = usofa.loc[usofa['State_y']=='VA']

print(state.shape)
# Out:
# (133, 43)

# %%
state.sample(10)
# Out:
#       CountyId   State_x                County  TotalPop     Men   Women  \
# 2839     51037  Virginia      Charlotte County     12176    5991    6185
# 2908     51185  Virginia       Tazewell County     42689   21055   21634
# 2865     51093  Virginia  Isle of Wight County     36090   17651   18439
# 2822     51005  Virginia      Alleghany County     15489    7586    7903
# 2830     51021  Virginia          Bland County      6524    3617    2907
# 2880     51125  Virginia         Nelson County     14863    7224    7639
# 2906     51181  Virginia          Surry County      6670    3213    3457
# 2840     51041  Virginia   Chesterfield County    335594  161644  173950
# 2850     51063  Virginia          Floyd County     15594    7842    7752
# 2868     51099  Virginia    King George County     25564   12839   12725
#
#       Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# 2839       2.1   67.5   29.6     0.1  ...        21.7           8.2
# 2908       0.9   94.0    3.0     0.2  ...        19.0           6.2
# 2865       2.8   70.8   22.3     0.3  ...        19.4           3.7
# 2822       1.4   91.9    5.5     0.0  ...        12.2           6.0
# 2830       0.5   94.3    4.8     0.0  ...        18.8           4.6
# 2880       3.9   81.6   12.6     0.2  ...        18.1          13.6
# 2906       0.8   52.1   45.6     0.0  ...        20.6           5.0
# 2840       8.2   62.8   22.4     0.2  ...        18.1           4.5
# 2850       2.8   93.7    2.5     0.2  ...        14.6           8.6
# 2868       4.6   73.8   16.4     0.2  ...        35.4           3.5
#
#       FamilyWork  Unemployment     FIPS  State_y           County_Name  \
# 2839         0.2           6.8  51037.0       VA      Charlotte County
# 2908         0.4           7.8  51185.0       VA       Tazewell County
# 2865         0.0           7.0  51093.0       VA  Isle of Wight County
# 2822         0.2           4.4  51005.0       VA      Alleghany County
# 2830         0.0           6.7  51021.0       VA          Bland County
# 2880         0.2           3.7  51125.0       VA         Nelson County
# 2906         0.2           7.7  51181.0       VA          Surry County
# 2840         0.1           5.6  51041.0       VA   Chesterfield County
# 2850         0.5           5.5  51063.0       VA          Floyd County
# 2868         0.1           4.9  51099.0       VA    King George County
#
#       Population_2010  RUCC_2013  \
# 2839          12586.0        8.0
# 2908          45078.0        5.0
# 2865          35270.0        1.0
# 2822          16250.0        6.0
# 2830           6824.0        8.0
# 2880          15020.0        3.0
# 2906           7058.0        8.0
# 2840         316236.0        1.0
# 2850          15279.0        3.0
# 2868          23584.0        6.0
#
#                                             Description
# 2839  Nonmetro - Completely rural or less than 2,500...
# 2908  Nonmetro - Urban population of 20,000 or more,...
# 2865  Metro - Counties in metro areas of 1 million p...
# 2822  Nonmetro - Urban population of 2,500 to 19,999...
# 2830  Nonmetro - Completely rural or less than 2,500...
# 2880  Metro - Counties in metro areas of fewer than ...
# 2906  Nonmetro - Completely rural or less than 2,500...
# 2840  Metro - Counties in metro areas of 1 million p...
# 2850  Metro - Counties in metro areas of fewer than ...
# 2868  Nonmetro - Urban population of 2,500 to 19,999...
#
# [10 rows x 43 columns]

# %%
usofa.loc[usofa['FIPS'].isna()][['CountyId','FIPS']]
# Out:
#       CountyId  FIPS
# 81        2158   NaN
# 2412     46102   NaN

# %%
usofa.loc[usofa['State_y'].isna()][['CountyId','State_y']]
# Out:
#       CountyId State_y
# 81        2158     NaN
# 2412     46102     NaN

# %%
usofa.isna().sum()
# Out:
# CountyId            0
# State_x             0
# County              0
# TotalPop            0
# Men                 0
# Women               0
# Hispanic            0
# White               0
# Black               0
# Native              0
# Asian               0
# Pacific             0
# VotingAgeCitizen    0
# Income              0
# IncomeErr           0
# IncomePerCap        0
# IncomePerCapErr     0
# Poverty             0
# ChildPoverty        1
# Professional        0
# Service             0
# Office              0
# Construction        0
# Production          0
# Drive               0
# Carpool             0
# Transit             0
# Walk                0
# OtherTransp         0
# WorkAtHome          0
# MeanCommute         0
# Employed            0
# PrivateWork         0
# PublicWork          0
# SelfEmployed        0
# FamilyWork          0
# Unemployment        0
# FIPS                2
# State_y             2
# County_Name         2
# Population_2010     2
# RUCC_2013           2
# Description         2
# dtype: int64

# %%
usofa.dropna()
# Out:
#       CountyId      State_x               County  TotalPop    Men   Women  \
# 0         1001      Alabama       Autauga County     55036  26899   28137
# 1         1003      Alabama       Baldwin County    203360  99527  103833
# 2         1005      Alabama       Barbour County     26201  13976   12225
# 3         1007      Alabama          Bibb County     22580  12251   10329
# 4         1009      Alabama        Blount County     57667  28490   29177
# ...        ...          ...                  ...       ...    ...     ...
# 3215     72145  Puerto Rico  Vega Baja Municipio     54754  26269   28485
# 3216     72147  Puerto Rico    Vieques Municipio      8931   4351    4580
# 3217     72149  Puerto Rico   Villalba Municipio     23659  11510   12149
# 3218     72151  Puerto Rico    Yabucoa Municipio     35025  16984   18041
# 3219     72153  Puerto Rico      Yauco Municipio     37585  18052   19533
#
#       Hispanic  White  Black  Native  ...  PublicWork  SelfEmployed  \
# 0          2.7   75.4   18.9     0.3  ...        20.2           5.6
# 1          4.4   83.1    9.5     0.8  ...        12.9           6.3
# 2          4.2   45.7   47.8     0.2  ...        19.1           6.5
# 3          2.4   74.6   22.0     0.4  ...        17.4           6.3
# 4          9.0   87.4    1.5     0.3  ...        11.9           4.0
# ...        ...    ...    ...     ...  ...         ...           ...
# 3215      96.7    3.1    0.1     0.0  ...        19.3           4.3
# 3216      95.7    4.0    0.0     0.0  ...        40.9          18.4
# 3217      99.7    0.2    0.1     0.0  ...        30.2          10.4
# 3218      99.9    0.1    0.0     0.0  ...        30.9           6.3
# 3219      99.8    0.2    0.0     0.0  ...        28.7           5.0
#
#       FamilyWork  Unemployment     FIPS  State_y          County_Name  \
# 0            0.1           5.2   1001.0       AL       Autauga County
# 1            0.1           5.5   1003.0       AL       Baldwin County
# 2            0.3          12.4   1005.0       AL       Barbour County
# 3            0.3           8.2   1007.0       AL          Bibb County
# 4            0.1           4.9   1009.0       AL        Blount County
# ...          ...           ...      ...      ...                  ...
# 3215         0.2          16.8  72145.0       PR  Vega Baja Municipio
# 3216         0.0          12.8  72147.0       PR    Vieques Municipio
# 3217         0.2          24.8  72149.0       PR   Villalba Municipio
# 3218         0.0          25.4  72151.0       PR    Yabucoa Municipio
# 3219         0.0          24.0  72153.0       PR      Yauco Municipio
#
#       Population_2010  RUCC_2013  \
# 0             54571.0        2.0
# 1            182265.0        3.0
# 2             27457.0        6.0
# 3             22915.0        1.0
# 4             57322.0        1.0
# ...               ...        ...
# 3215          59662.0        1.0
# 3216           9301.0        7.0
# 3217          26073.0        2.0
# 3218          37941.0        1.0
# 3219          42043.0        2.0
#
#                                             Description
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# 2     Nonmetro - Urban population of 2,500 to 19,999...
# 3     Metro - Counties in metro areas of 1 million p...
# 4     Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3215  Metro - Counties in metro areas of 1 million p...
# 3216  Nonmetro - Urban population of 2,500 to 19,999...
# 3217  Metro - Counties in metro areas of 250,000 to ...
# 3218  Metro - Counties in metro areas of 1 million p...
# 3219  Metro - Counties in metro areas of 250,000 to ...
#
# [3217 rows x 43 columns]

# %%
usofa.loc[usofa['Population_2010'].isna()][['CountyId','Population_2010']]
# Out:
#       CountyId  Population_2010
# 81        2158              NaN
# 2412     46102              NaN

# %%
pd.isnull(usofa)
# Out:
#       CountyId  State_x  County  TotalPop    Men  Women  Hispanic  White  \
# 0        False    False   False     False  False  False     False  False
# 1        False    False   False     False  False  False     False  False
# 2        False    False   False     False  False  False     False  False
# 3        False    False   False     False  False  False     False  False
# 4        False    False   False     False  False  False     False  False
# ...        ...      ...     ...       ...    ...    ...       ...    ...
# 3215     False    False   False     False  False  False     False  False
# 3216     False    False   False     False  False  False     False  False
# 3217     False    False   False     False  False  False     False  False
# 3218     False    False   False     False  False  False     False  False
# 3219     False    False   False     False  False  False     False  False
#
#       Black  Native  ...  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0     False   False  ...       False         False       False         False
# 1     False   False  ...       False         False       False         False
# 2     False   False  ...       False         False       False         False
# 3     False   False  ...       False         False       False         False
# 4     False   False  ...       False         False       False         False
# ...     ...     ...  ...         ...           ...         ...           ...
# 3215  False   False  ...       False         False       False         False
# 3216  False   False  ...       False         False       False         False
# 3217  False   False  ...       False         False       False         False
# 3218  False   False  ...       False         False       False         False
# 3219  False   False  ...       False         False       False         False
#
#        FIPS  State_y  County_Name  Population_2010  RUCC_2013  Description
# 0     False    False        False            False      False        False
# 1     False    False        False            False      False        False
# 2     False    False        False            False      False        False
# 3     False    False        False            False      False        False
# 4     False    False        False            False      False        False
# ...     ...      ...          ...              ...        ...          ...
# 3215  False    False        False            False      False        False
# 3216  False    False        False            False      False        False
# 3217  False    False        False            False      False        False
# 3218  False    False        False            False      False        False
# 3219  False    False        False            False      False        False
#
# [3220 rows x 43 columns]
